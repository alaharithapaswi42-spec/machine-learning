# %% [markdown]
# <a href="https://colab.research.google.com/github/alaharithapaswi42-spec/machine-learning/blob/main/titanic%20EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# PROJECT 1: TITANIC SURVIVAL - EDA

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
df = sns.load_dataset("titanic")

# -------------------------------
# 1. Basic Information
# -------------------------------

print("First 5 rows:")
print(df.head())

print("\nShape:")
print(df.shape)

print("\nDataset Information:")
print(df.info())

print("\nMissing Values:")
print(df.isnull().sum())

print("\nStatistical Summary:")
print(df.describe())

# -------------------------------
# 2. Target Distribution
# -------------------------------

sns.countplot(data=df, x="survived")
plt.title("Survival Distribution")
plt.show()

# -------------------------------
# 3. Survival by Sex
# -------------------------------

sns.countplot(data=df, x="sex", hue="survived")
plt.title("Survival by Gender")
plt.show()

# -------------------------------
# 4. Survival by Passenger Class
# -------------------------------

sns.countplot(data=df, x="class", hue="survived")
plt.title("Survival by Passenger Class")
plt.show()

# -------------------------------
# 5. Age Distribution
# -------------------------------

sns.histplot(data=df, x="age", kde=True)
plt.title("Age Distribution")
plt.show()

# -------------------------------
# 6. Correlation
# -------------------------------

numeric_df = df.select_dtypes(include=["int64", "float64"])

sns.heatmap(
    numeric_df.corr(),
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Correlation Heatmap")
plt.show()

print("\nEDA Completed Successfully.")
# Out:
# First 5 rows:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
#
# Shape:
# (891, 15)
#
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ...

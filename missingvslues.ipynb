# %% [markdown]
# <a href="https://colab.research.google.com/github/alaharithapaswi42-spec/machine-learning/blob/main/missingvslues.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("\nDataset shape:")
print(df.shape)

print("\nMissing values:")
print(df.isnull().sum())
# Out:
# Dataset shape:
# (20640, 9)
#
# Missing values:
# MedInc         0
# HouseAge       0
# AveRooms       0
# AveBedrms      0
# Population     0
# AveOccup       0
# Latitude       0
# Longitude      0
# MedHouseVal    0
# dtype: int64

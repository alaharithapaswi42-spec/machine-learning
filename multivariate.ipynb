# %% [markdown]
# <a href="https://colab.research.google.com/github/alaharithapaswi42-spec/machine-learning/blob/main/multivariate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#MULTIVARIATE ANALYSIS
#===============
plt.figure(figsize=(12,8))
sns.heatmap(
    df.select_dtypes(include=["int64","float64"]).corr(),
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)
plt.title("Correlation Heatmap")
plt.show()
#Pair Plot
sns.pairplot(
    df[
        [
            "CGPA",
            "AttendancePercent",
            "CodingTestScore",
            "AptitudeTestScore",
            "PlacementStatus"
        ]
    ],
    hue="PlacementStatus"
)
plt.show()
print("\nEDA Completed Successfully")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_696/1625508789.py in <cell line: 0>()
#       1 #MULTIVARIATE ANALYSIS
#       2 #===============
# ----> 3 plt.figure(figsize=(12,8))
#       4 sns.heatmap(
#       5     df.select_dtypes(include=["int64","float64"]).corr(),
#
# NameError: name 'plt' is not defined

# %% [markdown]
# <a href="https://colab.research.google.com/github/alaharithapaswi42-spec/machine-learning/blob/main/multivariate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================
# MULTIVARIATE ANALYSIS
# ============================================

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# ============================================
# 1. CORRELATION HEATMAP
# ============================================

plt.figure(figsize=(12, 8))

# Select only numerical columns
numeric_df = df.select_dtypes(include=["int64", "float64"])

# Calculate correlation
correlation = numeric_df.corr()

# Create heatmap
sns.heatmap(
    correlation,
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()


# ============================================
# 2. PAIR PLOT
# ============================================

# Select required columns
pair_data = df[
    [
        "CGPA",
        "AttendancePercent",
        "CodingTestScore",
        "AptitudeTestScore",
        "PlacementStatus"
    ]
]

# Create pair plot
sns.pairplot(
    pair_data,
    hue="PlacementStatus"
)

plt.show()


# ============================================
# 3. COMPLETION MESSAGE
# ============================================

print("\nEDA Completed Successfully!")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_6699/1466100395.py in <cell line: 0>()
#      38
#      39 # Select required columns
# ---> 40 pair_data = df[
#      41     [
#      42         "CGPA",
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# ...
